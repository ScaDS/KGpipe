# %%
# imports
import src.kgpipe_search
from src.kgpipe_search.configuration import enumerate_exhaustive_pipeline_config_snapshots

# %% [markdown]
# Enumerate all pipeline configs

# %%
enumerate_exhaustive_pipeline_config_snapshots()
